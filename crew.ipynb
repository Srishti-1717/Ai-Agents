# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Agent, Task, Crew

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\91888\Downloads\proj2_agent

# %%
from utils.api_utils import get_openai_api_key

print(get_openai_api_key())
# Out:
# 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

# %%
import sys
import os

# Get the current working directory
current_dir = os.getcwd()
sys.path.insert(0, current_dir)

from utils.api_utils import get_openai_api_key

print(get_openai_api_key())
# Out:
# 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

# %%
import os
from utils.api_utils import get_openai_api_key

openai_api_key = get_openai_api_key()
os.environ["OPENAI_MODEL_NAME"] = 'gpt-3.5-turbo'

# %%
from crewai import Agent

planner = Agent(
    role="Content Planner",
    goal="Plan engaging and factually accurate content on {topic}",
    backstory=("You're working on planning a blog article "
              "about the topic: {topic}."
              "You collect information that helps the "
              "audience learn something "
              "and make informed decisions. "
              "Your work is the basis for "
              "the Content Writer to write an article on this topic."),
    allow_delegation=False,
	verbose=True
)

# %%
writer = Agent(
    role="Content Writer",
    goal="Write insightful and factually accurate "
         "opinion piece about the topic: {topic}",
    backstory=("You're working on a writing "
              "a new opinion piece about the topic: {topic}. "
              "You base your writing on the work of "
              "the Content Planner, who provides an outline "
              "and relevant context about the topic. "
              "You follow the main objectives and "
              "direction of the outline, "
              "as provide by the Content Planner. "
              "You also provide objective and impartial insights "
              "and back them up with information "
              "provide by the Content Planner. "
              "You acknowledge in your opinion piece "
              "when your statements are opinions "
              "as opposed to objective statements."),
    allow_delegation=False,
    verbose=True
)

# %%
editor = Agent(
    role="Editor",
    goal="Edit a given blog post to align with "
         "the writing style of the organization. ",
    backstory=("You are an editor who receives a blog post "
              "from the Content Writer. "
              "Your goal is to review the blog post "
              "to ensure that it follows journalistic best practices,"
              "provides balanced viewpoints "
              "when providing opinions or assertions, "
              "and also avoids major controversial topics "
              "or opinions when possible."),
    allow_delegation=False,
    verbose=True
)

# %%
from crewai import Task
plan = Task(
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output=("A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources."),
    agent=planner,
)

# %%
write = Task(
    description=(
        "1. Use the content plan to craft a compelling "
            "blog post on {topic}.\n"
        "2. Incorporate SEO keywords naturally.\n"
		"3. Sections/Subtitles are properly named "
            "in an engaging manner.\n"
        "4. Ensure the post is structured with an "
            "engaging introduction, insightful body, "
            "and a summarizing conclusion.\n"
        "5. Proofread for grammatical errors and "
            "alignment with the brand's voice.\n"
    ),
    expected_output=("A well-written blog post "
        "in markdown format, ready for publication, "
        "each section should have 2 or 3 paragraphs."),
    agent=writer,
)

# %%
edit = Task(
    description=("Proofread the given blog post for "
                 "grammatical errors and "
                 "alignment with the brand's voice."),
    expected_output=("A well-written blog post in markdown format, "
                    "ready for publication, "
                    "each section should have 2 or 3 paragraphs."),
    agent=editor
)

# %%
from crewai import Crew
crew = Crew(
    agents=[planner, writer, editor],
    tasks=[plan, write, edit],
    verbose=True
)

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
result = crew.kickoff(inputs={"topic": "Artificial Intelligence"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 129ba85b-4ff1-47c2-b521-d92cf7c7adaf                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Task: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.
# 2. Identify the target audience, considering their interests and pain points.
# 3. Develop a detailed content outline including an introduction, key points, and a call to action.
# 4. Include SEO keywords and relevant data or sources.
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: In Progress
#         └── 🧠 Thinking...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Final Answer:
# Content Plan on Artificial Intelligence:
#
# Title: Unveiling the Power of Artificial Intelligence: Trends, Players, and Future Impacts
#
# Outline:
# I. Introduction
# - Definition of Artificial Intelligence
# - Significance and relevance in today's world
#
# II. Latest Trends in Artificial Intelligence
# - Machine Learning and Deep Learning advancements
# - Natural Language Processing innovations
# - Robotics and automation applications
# - AI in healthcare, finance, and other industries
#
# III. Key Players in the AI Industry
# - Big tech companies: Google, Amazon, Microsoft, etc.
# - AI startups disrupting industries
# - Research institutions and academia driving AI innovation
#
# IV. Noteworthy News in AI
# - Recent breakthroughs and developments
# - Ethical considerations and challenges in AI
# - Government regulations and policies in AI implementation
#
# V. Target Audience Analysis
# - Professionals in tech industries seeking insights on AI trends
# - Business owners interested in AI applications for their companies
# - Students and researchers exploring AI advancements
# - General audience curious about the future of AI
#
# VI. SEO Keywords:
# 1. Artificial Intelligence Trends
# 2. Key Players in AI Industry
# 3. Future Impacts of AI
# 4. Noteworthy News in Artificial Intelligence
# 5. AI Innovations and Developments
#
# VII. Resources:
# 1. Forbes - For latest news on AI trends and industry players
# 2. MIT Technology Review - For in-depth articles on AI advancements
# 3. Gartner - For market research and insights on AI applications
# 4. Stanford University AI Lab - For academic research and publications on AI
#
# VIII. Call to Action
# - Encourage readers to stay informed on AI advancements
# - Invite engagement through sharing opinions and experiences with AI
# - Provide links for further reading and exploration on AI topics
#
# This content plan aims to educate and engage the target audience regarding the latest trends, key players, and significant news in the field of Artificial Intelligence, catering to both industry professionals and general enthusiasts.
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: ✅ Completed
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Assigned to: Content Planner
#        Status: ✅ Completed
#     └── 🤖 Agent: Content Planner
#             Status: ✅ Completed
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: bd2923c8-981c-4ef2-9286-f6cd98f8ca04                                                                     │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Writer
# ## Task: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.
# 2. Incorporate SEO keywords naturally.
# 3. Sections/Subtitles are properly named in an engaging manner.
# 4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing conclusion.
# 5. Proofread for grammatical errors and alignment with the brand's voice.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: In Progress
#         └── 🧠 Thinking...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Writer
# ## Final Answer:
# # Unveiling the Power of Artificial Intelligence: Trends, Players, and Future Impacts
#
# ## Introduction
# Artificial Intelligence (AI) has become an integral part of our modern world, transforming industries, revolutionizing processes, and sparking curiosity about its future implications. Defined as the simulation of human intelligence processes by machines, AI holds immense significance in enhancing efficiencies, improving decision-making, and enabling innovations across various sectors. As AI continues to evolve rapidly, understanding its latest trends, key players, and potential impacts is crucial for professionals, businesses, researchers, and the general audience.
#
# ## Latest Trends in Artificial Intelligence
# The realm of AI is witnessing groundbreaking advancements in Machine Learning and Deep Learning, empowering systems to learn from data and make autonomous decisions. Moreover, innovations in Natural Language Processing are revolutionizing communication between machines and humans, paving the way for seamless interactions and personalized experiences. In parallel, robotics and automation applications are reshaping industries by enhancing productivity and efficiency, leading to the integration of AI in healthcare for improved diagnostics and personalized treatment plans, as well as in finance for better risk management and customer service.
#
# ## Key Players in the AI Industry
# The landscape of the AI industry is dominated by tech giants such as Google, Amazon, and Microsoft, investing heavily in AI research and development to drive innovation and shape future trends. Alongside these industry leaders, AI startups are disrupting traditional business models by offering niche solutions and agile approaches to problem-solving. Furthermore, research institutions and academia play a pivotal role in advancing AI technology through cutting-edge research, collaborations, and knowledge sharing, thereby fueling the continuous evolution of the field.
#
# ## Noteworthy News in AI
# Keeping abreast of recent breakthroughs and developments in AI is essential to grasp the pace of innovation and anticipate future trends. However, ethical considerations and challenges in AI implementation raise significant concerns regarding data privacy, algorithm bias, and machine decision-making processes. Consequently, the formulation of government regulations and policies becomes imperative to ensure responsible AI adoption and mitigate potential risks in deploying AI technologies across diverse sectors.
#
# ## Target Audience Analysis
# Professionals in tech industries seeking insights on AI trends, business owners exploring AI applications for their companies, students and researchers delving into AI advancements, and the general audience curious about the future of AI constitute the diverse target audience for understanding the evolving landscape of AI. Tailoring content to address their specific interests and knowledge levels is essential for engaging and informing them about the latest trends, key players, and significant news in the AI domain.
#
# ## Resources
# For staying informed and updated on AI trends, industry players, and technological advancements, reputable sources such as Forbes, MIT Technology Review, Gartner, and Stanford University AI Lab offer valuable insights, research findings, and expert opinions. Leveraging these resources can provide a comprehensive understanding of AI developments, ethical considerations, and regulatory frameworks shaping the future trajectory of AI innovation.
#
# ## Call to Action
# To encourage ongoing engagement and knowledge-sharing on AI topics, readers are invited to explore further readings, share their opinions and experiences with AI, and participate in discussions regarding the potential impacts and ethical implications of AI technologies. By fostering a collaborative learning environment and promoting informed conversations, individuals can contribute to the responsible and sustainable adoption of AI advancements in diverse industries and societal contexts.
#
# In conclusion, the captivating realm of Artificial Intelligence unfolds an exciting journey of transformative possibilities, ethical dilemmas, and technological innovations. By embracing the dynamic landscape of AI trends, understanding the key players driving innovation, and staying informed on noteworthy news in the field, individuals can navigate the complexities of AI with informed perspectives and forward-thinking strategies. Embracing the power of AI with curiosity, critical thinking, and ethical awareness will shape a future where artificial intelligence augments human capabilities, fosters innovation, and creates a more connected and intelligent world.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: ✅ Completed
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Assigned to: Content Writer
#        Status: ✅ Completed
#     └── 🤖 Agent: Content Writer
#             Status: ✅ Completed
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: a5a0e5ea-b376-4350-8453-63d792bfeae3                                                                     │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Editor
# ## Task: Proofread the given blog post for grammatical errors and alignment with the brand's voice.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: In Progress
#         └── 🧠 Thinking...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Editor
# ## Final Answer:
# # Unveiling the Power of Artificial Intelligence: Trends, Players, and Future Impacts
#
# ## Introduction
# Artificial Intelligence (AI) has become a vital component of our contemporary world, reshaping industries, redefining processes, and evoking fascination about its future ramifications. By simulating human intelligence processes through machines, AI plays a pivotal role in enhancing efficiencies, optimizing decision-making, and fostering innovations across diverse sectors. In light of AI's rapid evolution, gaining insights into its latest trends, key industry players, and potential impacts is essential for professionals, businesses, researchers, and the general audience.
#
# ## Latest Trends in Artificial Intelligence
# The domain of AI is experiencing groundbreaking progress in Machine Learning and Deep Learning, empowering systems to glean insights from data and autonomously make decisions. In addition, advancements in Natural Language Processing are revolutionizing human-machine communication, ushering in an era of seamless interactions and personalized experiences. Concurrently, applications of robotics and automation are reshaping industries, boosting productivity and effectiveness. This integration of AI spans various sectors such as healthcare, enhancing diagnostics and treatment plans, and finance, improving risk management and customer service.
#
# ## Key Players in the AI Industry
# Big tech corporations like Google, Amazon, and Microsoft drive the landscape of the AI industry, investing significantly in research and development to push boundaries and shape future trends. Complementing these industry giants, AI startups are disrupting conventional business models by offering specialized solutions and nimble problem-solving approaches. Furthermore, research institutions and academia are at the forefront of propelling AI technology through pioneering research, collaborations, and knowledge exchange, catalyzing the continual advancement of the field.
#
# ## Noteworthy News in AI
# Staying updated on recent breakthroughs and developments in AI is crucial to comprehend the pace of innovation and predict future trends. However, ethical dilemmas and challenges in AI implementation raise noteworthy concerns related to data privacy, algorithmic bias, and machine decision-making processes. Consequently, the development of governmental regulations and policies becomes imperative to ensure responsible AI integration and mitigate potential risks associated with deploying AI technologies across various domains.
#
# ## Target Audience Analysis
# The diverse target audience interested in grasping the evolving landscape of AI includes professionals in the tech sector seeking AI insights, business owners exploring AI applications for their companies, students and researchers delving into AI advancements, and the general audience intrigued by AI's future. Tailoring content to cater to their specific interests and expertise levels is key to engaging and educating them on the latest trends, prominent industry players, and significant news in the AI realm.
#
# ## Resources
# For reliable information and updates on AI trends, industry leaders, and technological advancements, esteemed sources like Forbes, MIT Technology Review, Gartner, and Stanford University AI Lab offer valuable insights, research findings, and expert perspectives. Leveraging these resources can furnish a comprehensive comprehension of AI progress, ethical considerations, and regulatory frameworks shaping the trajectory of AI innovation.
#
# ## Call to Action
# To encourage sustained engagement and knowledge-sharing on AI topics, readers are encouraged to delve into additional readings, share their thoughts and experiences with AI, and partake in dialogues concerning the potential impacts and ethical implications of AI technologies. By nurturing a collaborative learning environment and fostering informed conversations, individuals can contribute to the responsible and sustainable utilization of AI advancements in varied industries and societal contexts.
#
# In essence, the captivating realm of Artificial Intelligence unfurls a riveting narrative of transformative opportunities, ethical quandaries, and technological breakthroughs. Embracing the dynamic panorama of AI trends, comprehending the key industry players propelling innovation, and remaining abreast of noteworthy developments in the field empower individuals to navigate the complexities of AI with astute perspectives and forward-thinking strategies. Embracing the potential of AI with inquisitiveness, analytical thinking, and ethical consciousness will mold a future where artificial intelligence enhances human capabilities, stimulates innovation, and forges a more interconnected and intelligent world.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: ✅ Completed
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Assigned to: Editor
#        Status: ✅ Completed
#     └── 🤖 Agent: Editor
#             Status: ✅ Completed
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: d76c912b-10a5-4287-8af1-87f988779d76                                                                     │
# │  Agent: Editor                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 129ba85b-4ff1-47c2-b521-d92cf7c7adaf                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from IPython.display import Markdown

Markdown(str(result))
# Out:
# # Unveiling the Power of Artificial Intelligence: Trends, Players, and Future Impacts
#
# ## Introduction
# Artificial Intelligence (AI) has become a vital component of our contemporary world, reshaping industries, redefining processes, and evoking fascination about its future ramifications. By simulating human intelligence processes through machines, AI plays a pivotal role in enhancing efficiencies, optimizing decision-making, and fostering innovations across diverse sectors. In light of AI's rapid evolution, gaining insights into its latest trends, key industry players, and potential impacts is essential for professionals, businesses, researchers, and the general audience.
#
# ## Latest Trends in Artificial Intelligence
# The domain of AI is experiencing groundbreaking progress in Machine Learning and Deep Learning, empowering systems to glean insights from data and autonomously make decisions. In addition, advancements in Natural Language Processing are revolutionizing human-machine communication, ushering in an era of seamless interactions and personalized experiences. Concurrently, applications of robotics and automation are reshaping industries, boosting productivity and effectiveness. This integration of AI spans various sectors such as healthcare, enhancing diagnostics and treatment plans, and finance, improving risk management and customer service.
#
# ## Key Players in the AI Industry
# Big tech corporations like Google, Amazon, and Microsoft drive the landscape of the AI industry, investing significantly in research and development to push boundaries and shape future trends. Complementing these industry giants, AI startups are disrupting conventional business models by offering specialized solutions and nimble problem-solving approaches. Furthermore, research institutions and academia are at the forefront of propelling AI technology through pioneering research, collaborations, and knowledge exchange, catalyzing the continual advancement of the field.
#
# ## Noteworthy News in AI
# Staying updated on recent breakthroughs and developments in AI is crucial to comprehend the pace of innovation and predict future trends. However, ethical dilemmas and challenges in AI implementation raise noteworthy concerns related to data privacy, algorithmic bias, and machine decision-making processes. Consequently, the development of governmental regulations and policies becomes imperative to ensure responsible AI integration and mitigate potential risks associated with deploying AI technologies across various domains.
#
# ## Target Audience Analysis
# The diverse target audience interested in grasping the evolving landscape of AI includes professionals in the tech sector seeking AI insights, business owners exploring AI applications for their companies, students and researchers delving into AI advancements, and the general audience intrigued by AI's future. Tailoring content to cater to their specific interests and expertise levels is key to engaging and educating them on the latest trends, prominent industry players, and significant news in the AI realm.
#
# ## Resources
# For reliable information and updates on AI trends, industry leaders, and technological advancements, esteemed sources like Forbes, MIT Technology Review, Gartner, and Stanford University AI Lab offer valuable insights, research findings, and expert perspectives. Leveraging these resources can furnish a comprehensive comprehension of AI progress, ethical considerations, and regulatory frameworks shaping the trajectory of AI innovation.
#
# ## Call to Action
# To encourage sustained engagement and knowledge-sharing on AI topics, readers are encouraged to delve into additional readings, share their thoughts and experiences with AI, and partake in dialogues concerning the potential impacts and ethical implications of AI technologies. By nurturing a collaborative learning environment and fostering informed conversations, individuals can contribute to the responsible and sustainable utilization of AI advancements in varied industries and societal contexts.
#
# In essence, the captivating realm of Artificial Intelligence unfurls a riveting narrative of transformative opportunities, ethical quandaries, and technological breakthroughs. Embracing the dynamic panorama of AI trends, comprehending the key industry players propelling innovation, and remaining abreast of noteworthy developments in the field empower individuals to navigate the complexities of AI with astute perspectives and forward-thinking strategies. Embracing the potential of AI with inquisitiveness, analytical thinking, and ethical consciousness will mold a future where artificial intelligence enhances human capabilities, stimulates innovation, and forges a more interconnected and intelligent world.

# %%
topic="Corruption in India"
result=crew.kickoff(inputs={"topic":topic})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 129ba85b-4ff1-47c2-b521-d92cf7c7adaf                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Task: 1. Prioritize the latest trends, key players, and noteworthy news on Corruption in India.
# 2. Identify the target audience, considering their interests and pain points.
# 3. Develop a detailed content outline including an introduction, key points, and a call to action.
# 4. Include SEO keywords and relevant data or sources.
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: In Progress
#         └── 🧠 Thinking...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Planner
# ## Final Answer:
# Title: Unveiling Corruption in India: Trends, Players, and Call for Action
#
# Outline:
# I. Introduction
#    A. Brief overview of corruption in India
#    B. Importance of understanding the latest trends and key players in the fight against corruption
# II. Latest Trends in Corruption in India
#    A. Increase in reported cases of corruption
#    B. Digitalization and technology in combating corruption
#    C. Impact of the COVID-19 pandemic on corruption
# III. Key Players in the Fight Against Corruption
#    A. Anti-corruption agencies and laws
#    B. Civil society organizations and activists
#    C. Private sector initiatives towards transparency
# IV. Noteworthy News on Corruption in India
#    A. Recent high-profile corruption scandals
#    B. Government initiatives to curb corruption
#    C. Global perceptions of corruption in India
# V. Target Audience Analysis
#    A. Concerned citizens looking to understand the issue better
#    B. Business professionals navigating corruption risks
#    C. Students and researchers interested in the socio-political landscape of India
# VI. SEO Keywords:
#    A. Corruption in India
#    B. Anti-corruption efforts
#    C. Indian corruption scandals
#    D. Transparency and accountability
# VII. Resources:
#    A. Transparency International India
#    B. Central Vigilance Commission
#    C. Reports from reputable news outlets such as The Hindu and The Times of India
# VIII. Call to Action
#    A. Encourage readers to stay informed and engage in anti-corruption activities
#    B. Provide resources for reporting corruption cases
# IX. Conclusion
#    A. Reiterate the importance of raising awareness and taking action against corruption in India
#
# By following this detailed content plan, the blog article on "Corruption in India" aims to engage the audience with informative and actionable insights into the complex issue of corruption in the country.
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Status: Executing Task...
#     └── 🤖 Agent: Content Planner
#             Status: ✅ Completed
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# └── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
#        Assigned to: Content Planner
#        Status: ✅ Completed
#     └── 🤖 Agent: Content Planner
#             Status: ✅ Completed
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: bd2923c8-981c-4ef2-9286-f6cd98f8ca04                                                                     │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Writer
# ## Task: 1. Use the content plan to craft a compelling blog post on Corruption in India.
# 2. Incorporate SEO keywords naturally.
# 3. Sections/Subtitles are properly named in an engaging manner.
# 4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing conclusion.
# 5. Proofread for grammatical errors and alignment with the brand's voice.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: In Progress
#         └── 🧠 Thinking...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Content Writer
# ## Final Answer:
# # Unveiling Corruption in India: Trends, Players, and Call for Action
#
# ## Introduction
#
# Corruption in India has long been a pervasive issue, deeply ingrained in its socio-political fabric. Understanding the latest trends and key players in the fight against corruption is crucial to combat this detrimental phenomenon effectively. In a country where corruption has seeped into various sectors, from bureaucracy to business, it is imperative to shed light on the ongoing efforts to tackle this challenge.
#
# ## Latest Trends in Corruption in India
#
# Recent years have witnessed a concerning increase in reported cases of corruption across different sectors. However, there is also a significant shift towards leveraging digitalization and technology in combating corruption. The use of tools like online platforms for reporting corruption and promoting transparency has started to show promise. Moreover, the COVID-19 pandemic has posed new challenges, with reports suggesting a surge in corruption related to relief funds and healthcare services.
#
# ## Key Players in the Fight Against Corruption
#
# Various entities play a crucial role in combating corruption in India. Anti-corruption agencies and stringent laws are essential in holding perpetrators accountable. Civil society organizations and activists contribute significantly by raising awareness and advocating for transparency. Additionally, the private sector has been increasingly focusing on initiatives that promote integrity and accountability, thus fostering a culture of anti-corruption practices.
#
# ## Noteworthy News on Corruption in India
#
# Recent high-profile corruption scandals have once again highlighted the deep-rooted nature of corruption in Indian society. However, there have been commendable government initiatives aimed at curbing corruption, though their effectiveness remains a subject of debate. The global perceptions of corruption in India also influence the country's reputation on the international stage, urging for more robust anti-corruption measures.
#
# ## Target Audience Analysis
#
# This article caters to a diverse audience, including concerned citizens seeking a deeper understanding of the issue, business professionals navigating corruption risks, and students and researchers interested in India's complex socio-political landscape. By providing insights into the various dimensions of corruption, it aims to empower individuals to contribute towards a corruption-free future.
#
# ## Resources
#
# For more in-depth information on corruption in India and anti-corruption efforts, valuable resources include Transparency International India, the Central Vigilance Commission, and reports from reputable news outlets like The Hindu and The Times of India. These sources offer comprehensive analysis and updates on the state of corruption in the country.
#
# ## Call to Action
#
# It is essential for readers to stay informed and actively engage in anti-corruption activities in their spheres of influence. Reporting corruption cases through appropriate channels and supporting initiatives that promote transparency and accountability are essential steps towards creating a more ethical and equitable society.
#
# ## Conclusion
#
# In conclusion, the fight against corruption in India requires collective action and sustained efforts from all stakeholders. By raising awareness, advocating for accountability, and participating in anti-corruption initiatives, we can contribute towards building a more transparent and just society. Let us continue to strive for a corruption-free India for the prosperity of all its citizens.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Status: Executing Task...
#     └── 🤖 Agent: Content Writer
#             Status: ✅ Completed
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# └── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
#        Assigned to: Content Writer
#        Status: ✅ Completed
#     └── 🤖 Agent: Content Writer
#             Status: ✅ Completed
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: a5a0e5ea-b376-4350-8453-63d792bfeae3                                                                     │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Editor
# ## Task: Proofread the given blog post for grammatical errors and alignment with the brand's voice.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: In Progress
#         └── 🧠 Thinking...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: In Progress
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# # Agent: Editor
# ## Final Answer:
# # Unveiling Corruption in India: Trends, Players, and Call for Action
#
# ## Introduction
#
# Corruption in India has long been a pervasive issue, deeply ingrained in its socio-political fabric. Understanding the latest trends and key players in the fight against corruption is crucial to combat this detrimental phenomenon effectively. In a country where corruption has seeped into various sectors, from bureaucracy to business, it is imperative to shed light on the ongoing efforts to tackle this challenge.
#
# ## Latest Trends in Corruption in India
#
# Recent years have witnessed a concerning increase in reported cases of corruption across different sectors. However, there is also a significant shift towards leveraging digitalization and technology in combating corruption. The use of tools like online platforms for reporting corruption and promoting transparency has started to show promise. Moreover, the COVID-19 pandemic has posed new challenges, with reports suggesting a surge in corruption related to relief funds and healthcare services.
#
# ## Key Players in the Fight Against Corruption
#
# Various entities play a crucial role in combating corruption in India. Anti-corruption agencies and stringent laws are essential in holding perpetrators accountable. Civil society organizations and activists contribute significantly by raising awareness and advocating for transparency. Additionally, the private sector has been increasingly focusing on initiatives that promote integrity and accountability, thus fostering a culture of anti-corruption practices.
#
# ## Noteworthy News on Corruption in India
#
# Recent high-profile corruption scandals have once again highlighted the deep-rooted nature of corruption in Indian society. However, there have been commendable government initiatives aimed at curbing corruption, though their effectiveness remains a subject of debate. The global perceptions of corruption in India also influence the country's reputation on the international stage, urging for more robust anti-corruption measures.
#
# ## Target Audience Analysis
#
# This article caters to a diverse audience, including concerned citizens seeking a deeper understanding of the issue, business professionals navigating corruption risks, and students and researchers interested in India's complex socio-political landscape. By providing insights into the various dimensions of corruption, it aims to empower individuals to contribute towards a corruption-free future.
#
# ## Resources
#
# For more in-depth information on corruption in India and anti-corruption efforts, valuable resources include Transparency International India, the Central Vigilance Commission, and reports from reputable news outlets like The Hindu and The Times of India. These sources offer comprehensive analysis and updates on the state of corruption in the country.
#
# ## Call to Action
#
# It is essential for readers to stay informed and actively engage in anti-corruption activities in their spheres of influence. Reporting corruption cases through appropriate channels and supporting initiatives that promote transparency and accountability are essential steps towards creating a more ethical and equitable society.
#
# ## Conclusion
#
# In conclusion, the fight against corruption in India requires collective action and sustained efforts from all stakeholders. By raising awareness, advocating for accountability, and participating in anti-corruption initiatives, we can contribute towards building a more transparent and just society. Let us continue to strive for a corruption-free India for the prosperity of all its citizens.
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Status: Executing Task...
#     └── 🤖 Agent: Editor
#             Status: ✅ Completed
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: bd2923c8-981c-4ef2-9286-f6cd98f8ca04
# │      Assigned to: Content Planner
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Planner
# │           Status: ✅ Completed
# ├── 📋 Task: a5a0e5ea-b376-4350-8453-63d792bfeae3
# │      Assigned to: Content Writer
# │      Status: ✅ Completed
# │   └── 🤖 Agent: Content Writer
# │           Status: ✅ Completed
# └── 📋 Task: d76c912b-10a5-4287-8af1-87f988779d76
#        Assigned to: Editor
#        Status: ✅ Completed
#     └── 🤖 Agent: Editor
#             Status: ✅ Completed
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: d76c912b-10a5-4287-8af1-87f988779d76                                                                     │
# │  Agent: Editor                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 129ba85b-4ff1-47c2-b521-d92cf7c7adaf                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from IPython.display import Markdown

Markdown(str(result))
# Out:
# # Unveiling Corruption in India: Trends, Players, and Call for Action
#
# ## Introduction
#
# Corruption in India has long been a pervasive issue, deeply ingrained in its socio-political fabric. Understanding the latest trends and key players in the fight against corruption is crucial to combat this detrimental phenomenon effectively. In a country where corruption has seeped into various sectors, from bureaucracy to business, it is imperative to shed light on the ongoing efforts to tackle this challenge.
#
# ## Latest Trends in Corruption in India
#
# Recent years have witnessed a concerning increase in reported cases of corruption across different sectors. However, there is also a significant shift towards leveraging digitalization and technology in combating corruption. The use of tools like online platforms for reporting corruption and promoting transparency has started to show promise. Moreover, the COVID-19 pandemic has posed new challenges, with reports suggesting a surge in corruption related to relief funds and healthcare services.
#
# ## Key Players in the Fight Against Corruption
#
# Various entities play a crucial role in combating corruption in India. Anti-corruption agencies and stringent laws are essential in holding perpetrators accountable. Civil society organizations and activists contribute significantly by raising awareness and advocating for transparency. Additionally, the private sector has been increasingly focusing on initiatives that promote integrity and accountability, thus fostering a culture of anti-corruption practices.
#
# ## Noteworthy News on Corruption in India
#
# Recent high-profile corruption scandals have once again highlighted the deep-rooted nature of corruption in Indian society. However, there have been commendable government initiatives aimed at curbing corruption, though their effectiveness remains a subject of debate. The global perceptions of corruption in India also influence the country's reputation on the international stage, urging for more robust anti-corruption measures.
#
# ## Target Audience Analysis
#
# This article caters to a diverse audience, including concerned citizens seeking a deeper understanding of the issue, business professionals navigating corruption risks, and students and researchers interested in India's complex socio-political landscape. By providing insights into the various dimensions of corruption, it aims to empower individuals to contribute towards a corruption-free future.
#
# ## Resources
#
# For more in-depth information on corruption in India and anti-corruption efforts, valuable resources include Transparency International India, the Central Vigilance Commission, and reports from reputable news outlets like The Hindu and The Times of India. These sources offer comprehensive analysis and updates on the state of corruption in the country.
#
# ## Call to Action
#
# It is essential for readers to stay informed and actively engage in anti-corruption activities in their spheres of influence. Reporting corruption cases through appropriate channels and supporting initiatives that promote transparency and accountability are essential steps towards creating a more ethical and equitable society.
#
# ## Conclusion
#
# In conclusion, the fight against corruption in India requires collective action and sustained efforts from all stakeholders. By raising awareness, advocating for accountability, and participating in anti-corruption initiatives, we can contribute towards building a more transparent and just society. Let us continue to strive for a corruption-free India for the prosperity of all its citizens.
